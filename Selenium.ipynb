# %%
! pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in a:\anaconda3\lib\site-packages (from selenium) (1.25.11)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# !pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Using cached webdriver_manager-3.4.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in a:\anaconda3\lib\site-packages (from webdriver_manager) (2.24.0)
# Collecting crayons
#   Using cached crayons-0.4.0-py2.py3-none-any.whl (4.6 kB)
# Collecting configparser
#   Using cached configparser-5.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: idna<3,>=2.5 in a:\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in a:\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in a:\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in a:\anaconda3\lib\site-packages (from requests->webdriver_manager) (2020.6.20)
# Requirement already satisfied: colorama in a:\anaconda3\lib\site-packages (from crayons->webdriver_manager) (0.4.4)
# Installing collected packages: crayons, configparser, webdriver-manager
# Successfully installed configparser-5.0.2 crayons-0.4.0 webdriver-manager-3.4.2

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
driver  = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\LENOVO\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
driver.get('https://www.naukri.com/data-scientist-jobs?k=data%20scientist')

# %%
job_title = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
# //*[@id="root"]/div[3]/div[2]/section[2]/div[2]/article[1]/div[1]/div/a

# %%
driver  = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
driver.get('https://www.naukri.com/data-scientist-jobs?k=data%20scientist')
jobs = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
company = driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

title = []
for i in range(len(jobs)):
    title.append(jobs[i].text)
    
data = pd.DataFrame(title)    

company_ = []
for i in range(len(company)):
    company_.append(company[i].text)

data['company'] = company_
data.to_csv('Job List.csv',index=False)
data
    
driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\LENOVO\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
data
# Out:
#                                                     0  \
# 0     SENIOR DATA SCIENTIST Â– BFSI Domain Experience
# 1    Analytics & AI Product Mgmt - Sr. Data Scientist
# 2                               Senior Data Scientist
# 3   Job Opening For the post of Data Scientist in ...
# 4                                  Sr. Data Scientist
# 5                              Digital Data Scientist
# 6                                      Data Scientist
# 7            Senior Data Scientist - SQL/Spark/Python
# 8                                      Data Scientist
# 9                     Senior Manager - Data Scientist
# 10                   Lead Programmer - Data Scientist
# 11                 Senior Programmer - Data Scientist
# 12           Senior Data Scientist, Product Analytics
# 13           Senior Data Scientist, Product Analytics
# 14                    Data Scientist - Process mining
# 15         Data Scientist / Machine Learning Engineer
# 16  Fresher / Data Scientist / Data Analyst / Powe...
# 17                   Lead Data Scientist - NLP/OpenCV
# 18                                Lead Data Scientist
# 19  Lead Data Scientist - Prescriptive Analytics/P...
#
#                                              company
# 0                             IBM India Pvt. Limited
# 1            GlaxoSmithKline Pharmaceuticals Limited
# 2            GlaxoSmithKline Pharmaceuticals Limited
# 3   Data Collection Infotech (India) Private Limited
# 4                                      Multi Recruit
# 5            GlaxoSmithKline Pharmaceuticals Limited
# 6                  Flipkart Internet Private Limited
# 7                      Datamatics Business Solutions
# 8                Virtusa Consulting Services Pvt Ltd
# 9            GlaxoSmithKline Pharmaceuticals Limited
# 10           GlaxoSmithKline Pharmaceuticals Limited
# 11           GlaxoSmithKline Pharmaceuticals Limited
# 12                                         Atlassian
# 13                                   ExecBoardinAsia
# 14               Shell India Markets Private Limited
# 15                            IBM India Pvt. Limited
# 16                               Excel PTP Solutions
# 17                                       Codersbrain
# 18                                     Rakuten, Inc.
# 19                                       Codersbrain

# %%
user = []
commnent = []

#initialize the driver
driver  = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()

# open the product page
url='https://www.sephora.com/product/fresh-rose-hyaluronic-acid-deep-hydration-moisturizer-P471237?icid2=new%20arrivals:p471237:product'
driver.get(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\Lendave Home\.wdm\drivers\chromedriver\win32\92.0.4515.43\chromedriver.exe] found in cache

# %%
# scrape the data from page
comments = driver.find_elements_by_xpath('//div[@class="css-1x44x6f eanm77i0"]')
user_id = driver.find_elements_by_xpath('//strong[@data-at="nickname"]')

# append the data to list
for i in range(len(user_id)):
    user.append(user_id[i].text)
  
for i in range(len(comments)):
    commnent.append(comments[i].text)

# %%
# navigate between pages
driver.find_element_by_xpath('//*[@id="ratings-reviews-container"]/div[2]/ul/li[3]/button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-87-cf1fb5a41c98> in <module>
# ----> 1 driver.find_element_by_xpath('//*[@id="ratings-reviews-container"]/div[2]/ul/li[7]/button').click()
#
# A:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# A:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# A:\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# A:\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="ratings-reviews-container"]/div[2]/ul/li[7]/button"}
#   (Session info: chrome=92.0.4515.107)

# %%
data = pd.DataFrame(user)  
data['commnents'] = commnent

data.to_csv('Sentiment.csv',index=False)
driver.close()

# %%
driver.close()

# %%
data
# Out:
#                   0                                          commnents
# 0            JessRx  I love this stuff! It feels lovely on my skin—...
# 1        Mimiromero  Meh! it's fine. I received this as a trial siz...
# 2          SiskoPup  I originally got this as a free sample and I a...
# 3    PinkandPierced  I just purchased this a second time because I ...
# 4    BeautybyBishop  I received this product for free from Fresh. I...
# 5   candicecastello  This is my answer to my oily/combo skin and it...
# 6       astraybunny  When I moved continents 4 years ago my skin be...
# 7    nineredberries  Really really happy with this face cream. Was ...
# 8            Kckate  I recieved this product complimentary in excha...
# 9       jennyjenn69  Love this! It makes you look super dewy! I fee...
# 10    Irisfithess10  This is seriously an amazing hydration face cr...
# 11         EpicMama  This moisturizer is sooooo good for my sensiti...
# 12           dortiz  I have aging dry skin this is the best product...
# 13       micky55179  This product leaves my skin with the most beau...
# 14      ayakobright  Absolutely love this moisturizer! Great for a ...
# 15          somya02  The fresh cream has been my favorite day time ...
# 16         jnkb2319  I recieved this product complimentary from Fre...
# 17      beauty7guru  Lightweight moisturizing cream that smells lik...
# 18       MrsReyes23  I’ve been using this as my day time moisturize...
# 19    BrownBeauty90  My face stays moisturized all day and its not ...
# 20  pinkballetshoes  I wanted to love it, I really did. When I went...
# 21        nocookie4  The cream is little more than heavier when I t...
# 22        SheileenO  I purchased this product because the Fresh moi...
# 23          Fanny24  it made my skin so dry, it's not hidrating as ...
# 24        giggles30  This is a great lightweight moisturizer that h...
# 25       cindygomes  I’ve been using this as my night moisturizer f...
# 26        lauren121  This cream really surprised me! I was expectin...
# 27     beautymama96  Fresh brand gifted me this product. The first ...
# 28          MimiENN  One of the best moistrizers that I've ever use...
# 29       allykwhite  I love this product so much! It made my skin s...
